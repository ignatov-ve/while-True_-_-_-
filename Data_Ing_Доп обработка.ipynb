# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('/home/vyacheslav/Рабочий стол/MoscHak/Еще ДС/MegaRelation_hackaton_11.csv', delimiter=',')
df
# Out:
#         Unnamed: 0  Unnamed: 0.1  id_зачисления  Статус  id_организации  \
# 0                0             0        1325954       0              30
# 1                1             1        2879918       0              30
# 2                2             2        2901258       0              30
# 3                3             3        2912724       0              30
# 4                4             4        2912819       0              30
# ...            ...           ...            ...     ...             ...
# 645304      722322        722322       26412667       1              45
# 645305      722323        722323       26413582       1              45
# 645306      722324        722324       26414272       0              45
# 645307      722325        722325       26414912       1              45
# 645308      722326        722326       26415197       1              45
#
#         id_услуги  week_day  week_day_d_zach  week_day_d_nach_zan  \
# ...

# %%
sns.catplot("date_nach_zan_year", "Статус", kind="box", data=df, aspect=2/1)
# Out:
# /home/vyacheslav/.local/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(14, 6))

sns.boxplot(df['Статус'], df['Срок_обучения'], palette='Set2')

plt.xlabel('Статус')
plt.ylabel('Срок_обучения')
plt.title('Distribution')
# Out:
# /home/vyacheslav/.local/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Distribution')

# %%
df[df['Срок_обучения'] > 7000]
# Out:
#         Unnamed: 0  id_зачисления  Статус  id_ученика  id_организации  \
# 540345      540345       17400136       0           3             132
# 540346      540346       17400202       1           1             132
# 574996      574996       18525014       1           1             132
# 621167      621167        3416473       0           3             132
# 621317      621317       18554612       1           1             132
# ...            ...            ...     ...         ...             ...
# 637499      637499       18553613       0           2             132
# 637500      637500       18553664       1           1             132
# 637507      637507       18555098       1           1             132
# 637508      637508       18557453       1           1             132
# 637509      637509       18557471       0           2             132
#
#         id_услуги  week_day  week_day_d_zach  week_day_d_nach_zan  \
# ...

# %%
df = df.drop(df[(df['Срок_обучения'] < 0)].index)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 724617 entries, 0 to 724812
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Unnamed: 0                    724617 non-null  int64
#  1   id_зачисления                 724617 non-null  int64
#  2   Статус                        724617 non-null  int64
#  3   id_ученика                    724617 non-null  int64
#  4   id_организации                724617 non-null  int64
#  5   id_услуги                     724617 non-null  int64
#  6   week_day                      724617 non-null  int64
#  7   week_day_d_zach               724617 non-null  int64
#  8   week_day_d_nach_zan           724617 non-null  int64
#  9   week_day_okon_zan             724617 non-null  int64
#  10  date_year                     724617 non-null  int64
#  11  date_month                    724617 non-null  int64
# ...

# %%
df.to_csv('/home/vyacheslav/Рабочий стол/MoscHak/Еще ДС/MegaRelation_hackaton_9.csv', encoding= 'utf-8')

# %%
df['date_nach_zan_year'].unique()
# Out:
# array([2014, 2010, 2015, 2012, 2008, 2009, 2013, 2011, 2016, 2017, 2018,
#        2020, 2019, 2007])

# %%
df.groupby('Статус')['id_зачисления'].count()
# Out:
# Статус
# 0    563290
# 1    161327
# Name: id_зачисления, dtype: int64

# %%
df1 = pd.read_csv('/home/vyacheslav/Рабочий стол/MoscHak/Еще ДС/MegaRelation_hackaton_9.csv', delimiter=',')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 722327 entries, 0 to 722326
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Unnamed: 0                    722327 non-null  int64
#  1   Unnamed: 0.1                  722327 non-null  int64
#  2   id_зачисления                 722327 non-null  int64
#  3   Статус                        722327 non-null  int64
#  4   id_ученика                    722327 non-null  int64
#  5   id_организации                722327 non-null  int64
#  6   id_услуги                     722327 non-null  int64
#  7   week_day                      722327 non-null  int64
#  8   week_day_d_zach               722327 non-null  int64
#  9   week_day_d_nach_zan           722327 non-null  int64
#  10  week_day_okon_zan             722327 non-null  int64
#  11  date_year                     722327 non-null  int64
# ...

# %% [markdown]
# ### РАЗБИНЕИНЕ

# %%
df2 = df[df['Срок_обучения'] <= 1000]

# %%
df2
# Out:
#         Unnamed: 0  Unnamed: 0.1  id_зачисления  Статус  id_организации  \
# 228            257           257        3052806       0              30
# 283            317           317        3067760       0              30
# 322            388           388          21345       0             156
# 326            392           392          21349       0             156
# 328            394           394          21351       0             156
# ...            ...           ...            ...     ...             ...
# 644916      721840        721840       14439209       1           90986
# 645074      722042        722042       25820213       0             130
# 645109      722082        722082       26969508       0              78
# 645228      722245        722245       19815448       1              29
# 645229      722246        722246       19823645       1              29
#
#         id_услуги  week_day  week_day_d_zach  week_day_d_nach_zan  \
# ...

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'id_зачисления', 'Статус',
#        'id_организации', 'id_услуги', 'week_day', 'week_day_d_zach',
#        'week_day_d_nach_zan', 'week_day_okon_zan', 'date_year', 'date_month',
#        'date_zach_year', 'date_zach_month', 'date_nach_zan_year',
#        'date_nach_zan_month', 'date_okon_zan_year', 'date_okon_zan_month',
#        'date_is_weekend', 'date_zach_is_weekend', 'date_nach_zan_is_weekend',
#        'week_day_okon_zan_is_weekend', 'Срок_обучения', 'id_ученика'],
#       dtype='object')

# %%
df2 = df2[['id_зачисления', 'Статус',
       'id_организации', 'id_услуги', 'week_day', 'week_day_d_zach',
       'week_day_d_nach_zan', 'week_day_okon_zan', 'date_year', 'date_month',
       'date_zach_year', 'date_zach_month', 'date_nach_zan_year',
       'date_nach_zan_month', 'date_okon_zan_year', 'date_okon_zan_month',
       'date_is_weekend', 'date_zach_is_weekend', 'date_nach_zan_is_weekend',
       'week_day_okon_zan_is_weekend', 'Срок_обучения', 'id_ученика']]
df2
# Out:
#         id_зачисления  Статус  id_организации  id_услуги  week_day  \
# 228           3052806       0              30      39178         1
# 283           3067760       0              30      39178         2
# 322             21345       0             156      87877         4
# 326             21349       0             156      87877         4
# 328             21351       0             156      87877         4
# ...               ...     ...             ...        ...       ...
# 644916       14439209       1           90986     606495         2
# 645074       25820213       0             130     727779         3
# 645109       26969508       0              78     963888         4
# 645228       19815448       1              29     728015         6
# 645229       19823645       1              29     728015         1
#
#         week_day_d_zach  week_day_d_nach_zan  week_day_okon_zan  date_year  \
# 228                   3                    3                  4       2015
# ...

# %%
df2.to_csv('/home/vyacheslav/Рабочий стол/MoscHak/Еще ДС/MegaRelation_hackaton_11_1.csv', encoding= 'utf-8')

# %%
df2
# Out:
#         id_зачисления  Статус  id_организации  id_услуги  week_day  \
# 228           3052806       0              30      39178         1
# 283           3067760       0              30      39178         2
# 322             21345       0             156      87877         4
# 326             21349       0             156      87877         4
# 328             21351       0             156      87877         4
# ...               ...     ...             ...        ...       ...
# 644916       14439209       1           90986     606495         2
# 645074       25820213       0             130     727779         3
# 645109       26969508       0              78     963888         4
# 645228       19815448       1              29     728015         6
# 645229       19823645       1              29     728015         1
#
#         week_day_d_zach  week_day_d_nach_zan  week_day_okon_zan  date_year  \
# 228                   3                    3                  4       2015
# ...

# %%
df2.drop (columns = ['Статус'])
# Out:
#         id_зачисления  id_организации  id_услуги  week_day  week_day_d_zach  \
# 228           3052806              30      39178         1                3
# 283           3067760              30      39178         2                5
# 322             21345             156      87877         4                4
# 326             21349             156      87877         4                4
# 328             21351             156      87877         4                4
# ...               ...             ...        ...       ...              ...
# 644916       14439209           90986     606495         2                2
# 645074       25820213             130     727779         3                5
# 645109       26969508              78     963888         4                2
# 645228       19815448              29     728015         6                4
# 645229       19823645              29     728015         1                4
#
# ...

# %%
df2.to_csv('/home/vyacheslav/Рабочий стол/MoscHak/Еще ДС/Pipeline 2/MegaRelation_hackaton_11_1_without.csv', encoding= 'utf-8')

# %%
df3 = df[df['Срок_обучения'] > 1000]

# %%
df3
# Out:
#         Unnamed: 0  Unnamed: 0.1  id_зачисления  Статус  id_организации  \
# 0                0             0        1325954       0              30
# 1                1             1        2879918       0              30
# 2                2             2        2901258       0              30
# 3                3             3        2912724       0              30
# 4                4             4        2912819       0              30
# ...            ...           ...            ...     ...             ...
# 645304      722322        722322       26412667       1              45
# 645305      722323        722323       26413582       1              45
# 645306      722324        722324       26414272       0              45
# 645307      722325        722325       26414912       1              45
# 645308      722326        722326       26415197       1              45
#
#         id_услуги  week_day  week_day_d_zach  week_day_d_nach_zan  \
# ...

# %%
df3 = df3[['id_зачисления', 'Статус', 'id_ученика',
       'id_организации', 'id_услуги', 'week_day', 'week_day_d_zach',
       'week_day_d_nach_zan', 'week_day_okon_zan', 'date_year', 'date_month',
       'date_zach_year', 'date_zach_month', 'date_nach_zan_year',
       'date_nach_zan_month', 'date_okon_zan_year', 'date_okon_zan_month',
       'date_is_weekend', 'date_zach_is_weekend', 'date_nach_zan_is_weekend',
       'week_day_okon_zan_is_weekend', 'Срок_обучения']]
df3
# Out:
#         id_зачисления  Статус  id_ученика  id_организации  id_услуги  \
# 0             1325954       0       25969              30      39178
# 1             2879918       0      158129              30      39178
# 2             2901258       0      304476              30      39178
# 3             2912724       0     1139915              30      39178
# 4             2912819       0      298767              30      39178
# ...               ...     ...         ...             ...        ...
# 645304       26412667       1     3818767              45     660705
# 645305       26413582       1      276784              45     660705
# 645306       26414272       0     1996628              45     660705
# 645307       26414912       1      259560              45     660705
# 645308       26415197       1     1996628              45     660705
#
#         week_day  week_day_d_zach  week_day_d_nach_zan  week_day_okon_zan  \
# ...

# %%
df3.drop (columns = ['Статус'])
# Out:
#         id_зачисления  id_ученика  id_организации  id_услуги  week_day  \
# 0             1325954       25969              30      39178         3
# 1             2879918      158129              30      39178         3
# 2             2901258      304476              30      39178         2
# 3             2912724     1139915              30      39178         2
# 4             2912819      298767              30      39178         2
# ...               ...         ...             ...        ...       ...
# 645304       26412667     3818767              45     660705         2
# 645305       26413582      276784              45     660705         2
# 645306       26414272     1996628              45     660705         2
# 645307       26414912      259560              45     660705         2
# 645308       26415197     1996628              45     660705         2
#
#         week_day_d_zach  week_day_d_nach_zan  week_day_okon_zan  date_year  \
# ...

# %%
df3.to_csv('/home/vyacheslav/Рабочий стол/MoscHak/Еще ДС/Pipeline 1/MegaRelation_hackaton_11_2_without.csv', encoding= 'utf-8')

# %%
df3.to_csv('/home/vyacheslav/Рабочий стол/MoscHak/Еще ДС/MegaRelation_hackaton_11_2.csv', encoding= 'utf-8')

# %% [markdown]
# ### ИСПРАВЛЕНИЕ КОСЯКА

# %%
df = pd.read_csv('/home/vyacheslav/Рабочий стол/MoscHak/Еще ДС/MegaRelation_hackaton.csv', delimiter=';')
df
# Out:
#         id_зачисления  Статус  id_ученика Дата_создания_записи  \
# 0             1325954     3.0     25969.0  08.06.2015 14:47:19
# 1             2879918     3.0    158129.0  29.10.2015 18:35:21
# 2             2901258     3.0    304476.0  02.11.2015 14:05:56
# 3             2912724     3.0   1139915.0  03.11.2015 14:29:27
# 4             2912819     3.0    298767.0  03.11.2015 14:34:15
# ...               ...     ...         ...                  ...
# 724808       26412667     1.0   3818767.0  12.11.2019 16:47:17
# 724809       26413582     1.0    276784.0  12.11.2019 16:55:08
# 724810       26414272     3.0   1996628.0  12.11.2019 17:01:58
# 724811       26414912     1.0    259560.0  12.11.2019 17:09:09
# 724812       26415197     1.0   1996628.0  12.11.2019 17:10:51
#
#         id_организации  id_заявления  id_услуги      дата_зачисления  \
# 0                   30      950832.0      39178   08.06.2015 0:00:00
# ...

# %%
df.columns
# Out:
# Index(['id_зачисления', 'Статус', 'id_ученика', 'Дата_создания_записи',
#        'id_организации', 'id_заявления', 'id_услуги', 'дата_зачисления',
#        'дата_отчисления', 'причина_перевода', 'предыдущая_запись_зачисления',
#        'следующая_запись_зачисления', 'Плановая_дата_начала_занятий',
#        'Плановая_дата_окончания_занятий'],
#       dtype='object')

# %%
df.drop(['Статус', 'Дата_создания_записи',
       'id_организации', 'id_заявления', 'id_услуги', 'дата_зачисления',
       'дата_отчисления', 'причина_перевода', 'предыдущая_запись_зачисления',
       'следующая_запись_зачисления', 'Плановая_дата_начала_занятий',
       'Плановая_дата_окончания_занятий'], axis='columns', inplace=True)

# %%
df
# Out:
#         id_зачисления  id_ученика
# 0             1325954     25969.0
# 1             2879918    158129.0
# 2             2901258    304476.0
# 3             2912724   1139915.0
# 4             2912819    298767.0
# ...               ...         ...
# 724808       26412667   3818767.0
# 724809       26413582    276784.0
# 724810       26414272   1996628.0
# 724811       26414912    259560.0
# 724812       26415197   1996628.0
#
# [724813 rows x 2 columns]

# %%
df.to_csv('/home/vyacheslav/Рабочий стол/MoscHak/Еще ДС/MegaRelation_hackaton_ученик_зачисление.csv', encoding= 'utf-8')

# %%
df1 = pd.read_csv('/home/vyacheslav/Рабочий стол/MoscHak/Еще ДС/MegaRelation_hackaton_9.csv', delimiter=',')
df1
# Out:
#         Unnamed: 0  Unnamed: 0.1  id_зачисления  Статус  id_ученика  \
# 0                0             0        1325954       0           3
# 1                1             1        2879918       0           3
# 2                2             2        2901258       0           3
# 3                3             3        2912724       0           3
# 4                4             4        2912819       0           3
# ...            ...           ...            ...     ...         ...
# 722322      724808        724808       26412667       1           1
# 722323      724809        724809       26413582       1           1
# 722324      724810        724810       26414272       0           3
# 722325      724811        724811       26414912       1           1
# 722326      724812        724812       26415197       1           1
#
#         id_организации  id_услуги  week_day  week_day_d_zach  \
# 0                   30      39178         3                3
# ...

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'id_зачисления', 'Статус', 'id_ученика',
#        'id_организации', 'id_услуги', 'week_day', 'week_day_d_zach',
#        'week_day_d_nach_zan', 'week_day_okon_zan', 'date_year', 'date_month',
#        'date_zach_year', 'date_zach_month', 'date_nach_zan_year',
#        'date_nach_zan_month', 'date_okon_zan_year', 'date_okon_zan_month',
#        'date_is_weekend', 'date_zach_is_weekend', 'date_nach_zan_is_weekend',
#        'week_day_okon_zan_is_weekend', 'Срок_обучения'],
#       dtype='object')

# %%
df1.drop(['Unnamed: 0', 'Unnamed: 0.1', 'id_ученика'], axis='columns', inplace=True)

# %%
df1
# Out:
#         id_зачисления  Статус  id_организации  id_услуги  week_day  \
# 0             1325954       0              30      39178         3
# 1             2879918       0              30      39178         3
# 2             2901258       0              30      39178         2
# 3             2912724       0              30      39178         2
# 4             2912819       0              30      39178         2
# ...               ...     ...             ...        ...       ...
# 722322       26412667       1              45     660705         2
# 722323       26413582       1              45     660705         2
# 722324       26414272       0              45     660705         2
# 722325       26414912       1              45     660705         2
# 722326       26415197       1              45     660705         2
#
#         week_day_d_zach  week_day_d_nach_zan  week_day_okon_zan  date_year  \
# 0                     3                    3                  5       2015
# ...

# %%
df1.to_csv('/home/vyacheslav/Рабочий стол/MoscHak/Еще ДС/MegaRelation_hackaton_без_ученика.csv', encoding= 'utf-8')

# %%
df2 = df1.merge(df, how='inner', on='id_зачисления')

# %%
df2
# Out:
#         id_зачисления  Статус  id_организации  id_услуги  week_day  \
# 0             1325954       0              30      39178         3
# 1             2879918       0              30      39178         3
# 2             2901258       0              30      39178         2
# 3             2912724       0              30      39178         2
# 4             2912819       0              30      39178         2
# ...               ...     ...             ...        ...       ...
# 722322       26412667       1              45     660705         2
# 722323       26413582       1              45     660705         2
# 722324       26414272       0              45     660705         2
# 722325       26414912       1              45     660705         2
# 722326       26415197       1              45     660705         2
#
#         week_day_d_zach  week_day_d_nach_zan  week_day_okon_zan  date_year  \
# 0                     3                    3                  5       2015
# ...

# %%
df2.to_csv('/home/vyacheslav/Рабочий стол/MoscHak/Еще ДС/MegaRelation_hackaton_11.csv', encoding= 'utf-8')

# %%
df = pd.read_csv('/home/vyacheslav/Рабочий стол/MoscHak/Еще ДС/MegaRelation_hackaton_11.csv', delimiter=',')
df
# Out:
#         Unnamed: 0  Unnamed: 0.1  id_зачисления  Статус  id_организации  \
# 0                0             0        1325954       0              30
# 1                1             1        2879918       0              30
# 2                2             2        2901258       0              30
# 3                3             3        2912724       0              30
# 4                4             4        2912819       0              30
# ...            ...           ...            ...     ...             ...
# 645304      722322        722322       26412667       1              45
# 645305      722323        722323       26413582       1              45
# 645306      722324        722324       26414272       0              45
# 645307      722325        722325       26414912       1              45
# 645308      722326        722326       26415197       1              45
#
#         id_услуги  week_day  week_day_d_zach  week_day_d_nach_zan  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 645309 entries, 0 to 645308
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Unnamed: 0                    645309 non-null  int64
#  1   Unnamed: 0.1                  645309 non-null  int64
#  2   id_зачисления                 645309 non-null  int64
#  3   Статус                        645309 non-null  int64
#  4   id_организации                645309 non-null  int64
#  5   id_услуги                     645309 non-null  int64
#  6   week_day                      645309 non-null  int64
#  7   week_day_d_zach               645309 non-null  int64
#  8   week_day_d_nach_zan           645309 non-null  int64
#  9   week_day_okon_zan             645309 non-null  int64
#  10  date_year                     645309 non-null  int64
#  11  date_month                    645309 non-null  int64
# ...

# %%
df['id_ученика'].unique()
# Out:
# array([  25969.,  158129.,  304476., ..., 1327210., 3818767.,  259560.])

# %%
df['id_ученика'].value_counts()
# Out:
# 410980.0     41
# 195381.0     35
# 801149.0     31
# 492471.0     30
# 32636.0      29
#              ..
# 22087.0       1
# 1413617.0     1
# 22088.0       1
# 3657540.0     1
# 1533252.0     1
# Name: id_ученика, Length: 288978, dtype: int64

# %%
df1 = df.dropna(axis = 0, how ='all', inplace = True)

# %%
df
# Out:
#         Unnamed: 0  id_зачисления  Статус  id_организации  id_услуги  \
# 0                0        1325954       0              30      39178
# 1                1        2879918       0              30      39178
# 2                2        2901258       0              30      39178
# 3                3        2912724       0              30      39178
# 4                4        2912819       0              30      39178
# ...            ...            ...     ...             ...        ...
# 722322      722322       26412667       1              45     660705
# 722323      722323       26413582       1              45     660705
# 722324      722324       26414272       0              45     660705
# 722325      722325       26414912       1              45     660705
# 722326      722326       26415197       1              45     660705
#
#         week_day  week_day_d_zach  week_day_d_nach_zan  week_day_okon_zan  \
# ...

# %%
df2 = df.dropna(axis = 0)

# %%
df2
# Out:
#         Unnamed: 0  id_зачисления  Статус  id_организации  id_услуги  \
# 0                0        1325954       0              30      39178
# 1                1        2879918       0              30      39178
# 2                2        2901258       0              30      39178
# 3                3        2912724       0              30      39178
# 4                4        2912819       0              30      39178
# ...            ...            ...     ...             ...        ...
# 722322      722322       26412667       1              45     660705
# 722323      722323       26413582       1              45     660705
# 722324      722324       26414272       0              45     660705
# 722325      722325       26414912       1              45     660705
# 722326      722326       26415197       1              45     660705
#
#         week_day  week_day_d_zach  week_day_d_nach_zan  week_day_okon_zan  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 645309 entries, 0 to 722326
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Unnamed: 0                    645309 non-null  int64
#  1   id_зачисления                 645309 non-null  int64
#  2   Статус                        645309 non-null  int64
#  3   id_организации                645309 non-null  int64
#  4   id_услуги                     645309 non-null  int64
#  5   week_day                      645309 non-null  int64
#  6   week_day_d_zach               645309 non-null  int64
#  7   week_day_d_nach_zan           645309 non-null  int64
#  8   week_day_okon_zan             645309 non-null  int64
#  9   date_year                     645309 non-null  int64
#  10  date_month                    645309 non-null  int64
#  11  date_zach_year                645309 non-null  int64
# ...

# %%
df2['id_ученика'] = df2['id_ученика'].astype(int)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df1['id_ученика'].unique()
# Out:
# array([3, 2, 1])

# %%
df1['id_зачисления'].unique()
# Out:
# array([ 1325954,  2879918,  2901258, ..., 26414272, 26414912, 26415197])

# %%
len(df1['id_зачисления'].unique())
# Out:
# 722327

# %%
df1.shape
# Out:
# (722327, 24)

# %%
df1['id_ученика'].value_counts()
# Out:
# 2    364343
# 3    196657
# 1    161327
# Name: id_ученика, dtype: int64

# %%
df1['id_организации'].unique()
# Out:
# array([   30,    45,   156,    78,   134,    28,   137,   141,   136,
#          152,   112,    51,   109,   110,    89,    29,    48,   154,
#          801,   118,   148,   145,   129,    34,    58,    99,   144,
#           92,    64,    42,    16,    20,    25,    82,   105,     4,
#          123,   121,    88,    19,    95,    56,    14,    81,   103,
#           26,    91,   114,    50,   116,    32,   146,    43,    13,
#          125,   132,    52,    11,    93,   128,    10,    21,    53,
#          162,    35,   117,    38,    59,    67,   102,    22,    79,
#           44,    31,   122,   143,   130,    12,   138,    77,   153,
#          161,   111,   108,    41,    80,    96,    97,    46,   101,
#           24,   100,    49,    33,    85,    40,   131,    94,   119,
#            9,    76,   106,     2,    15,    17,    23,    90,     8,
#          139,    83,   107,   140,    37,    55,   133,   113,    36,
# ...

# %%
len(df1['id_организации'].unique())
# Out:
# 238

# %%
df1['id_организации'].value_counts()
# Out:
# 10897    15453
# 10887    14169
# 10912    13558
# 59       11838
# 10907    11672
#          ...
# 10866       32
# 90986       28
# 10919       20
# 10902       18
# 46077       12
# Name: id_организации, Length: 238, dtype: int64

# %%
df1['id_ученика']
# Out:
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
#          ..
# 722322    1
# 722323    1
# 722324    3
# 722325    1
# 722326    1
# Name: id_ученика, Length: 722327, dtype: int64

# %%
df = pd.read_csv('/home/vyacheslav/Рабочий стол/MoscHak/Еще ДС/MegaRelation_hackaton.csv', delimiter=';')
df
# Out:
#         id_зачисления  Статус  id_ученика Дата_создания_записи  \
# 0             1325954     3.0     25969.0  08.06.2015 14:47:19
# 1             2879918     3.0    158129.0  29.10.2015 18:35:21
# 2             2901258     3.0    304476.0  02.11.2015 14:05:56
# 3             2912724     3.0   1139915.0  03.11.2015 14:29:27
# 4             2912819     3.0    298767.0  03.11.2015 14:34:15
# ...               ...     ...         ...                  ...
# 724808       26412667     1.0   3818767.0  12.11.2019 16:47:17
# 724809       26413582     1.0    276784.0  12.11.2019 16:55:08
# 724810       26414272     3.0   1996628.0  12.11.2019 17:01:58
# 724811       26414912     1.0    259560.0  12.11.2019 17:09:09
# 724812       26415197     1.0   1996628.0  12.11.2019 17:10:51
#
#         id_организации  id_заявления  id_услуги      дата_зачисления  \
# 0                   30      950832.0      39178   08.06.2015 0:00:00
# ...

# %%
df['id_ученика']
# Out:
# 0           25969.0
# 1          158129.0
# 2          304476.0
# 3         1139915.0
# 4          298767.0
#             ...
# 724808    3818767.0
# 724809     276784.0
# 724810    1996628.0
# 724811     259560.0
# 724812    1996628.0
# Name: id_ученика, Length: 724813, dtype: float64
